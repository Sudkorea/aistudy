# %% [markdown]
# # 2 파이썬 속성 강좌

# %%
def factorial(x: int) -> int:
    if x==0 or x==1:
        return 1
    else:
        return x * factorial(x-1)

# %%
assert factorial(5) == 120, "something went wrong"

assert factorial(0) == 0, "수학의수치"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 assert factorial(5) == 120, "something went wrong"
# ----> 3 assert factorial(0) == 0, "수학의수치"
#
# AssertionError: 수학의수치

# %% [markdown]
# # 3 데이터 시각화

# %%
import matplotlib.pyplot as plt

# %%
years = range(1950, 2020, 10)
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title('Nomial GDP')

plt.xlabel("years")
plt.ylabel("Billions of $")

plt.show()

# %%
movies = ['Annie Hall', "Ben-Hur", 'Casablanca', 'Gandhi', "west side story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
plt.bar(range(len(movies)), num_oscars)

plt.title("He's favorite movies")
plt.ylabel('# of academy awards')

plt.xticks(range(len(movies)), movies)

plt.show()

# %%
from collections import Counter

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10* 10, 90) for grade in grades)

print(histogram.items())
# Out:
# dict_items([(80, 4), (90, 3), (70, 3), (0, 2), (60, 1)])

# %%
plt.bar([x+5 for x in histogram.keys()], # 5만큼 오른쪽으로 땡겨서 보기좋게
        histogram.values(),  # y축 설정해주고
        10, # 너비 설정
        edgecolor = (0,0,0) # 막대기 테두리 RGB
        )

plt.axis([-5, 105, 0, 5]) #x축은 -5~105, y축은 0~5

plt.xticks([10 * i for i in range(11)])
plt.xlabel('Decile')
plt.ylabel('# of students')
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i in range(len(variance))]

# %%
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

plt.legend(loc=9)
plt.xlabel('model complexity')
plt.xticks([])
plt.title('The bias-variance tradeoff')
plt.show()

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                 xy=(friend_count, minute_count), #x, y좌표 찝어주기
                 xytext=(5, -5), # x축 5(pt정도로 추정), y축 -5만큼 떨어지게 찍기
                 textcoords='offset points')
    
plt.title("Daily Minutes vs Number of Friends")
plt.xlabel("# of friends")
plt.ylabel('daily minutes spent on the site')
plt.show()

# %%
test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
# plt.axis('equal')
plt.title("Axes Aren't Comparable")
plt.xlabel('test 1 grade')
plt.ylabel('test 2 grade')
plt.show()
